# %%
import os
import glob
import math
import pickle

import numpy as np
import pandas as pd
import geopandas as gpd
import torch

import os
import pandas as pd
import geopandas as gpd
import xml.etree.ElementTree as ET
import gzip
import json
import fiona
from collections import defaultdict
from torch_geometric.transforms import LineGraph
from torch_geometric.data import Data, Batch
import fiona


highway_mapping = {
    'trunk': 0, 'trunk_link': 0, 'motorway_link': 0,
    'primary': 1, 'primary_link': 1,
    'secondary': 2, 'secondary_link': 2,
    'tertiary': 3, 'tertiary_link': 3,
    'residential': 4, 'living_street': 5,
    'pedestrian': 6, 'service': 7,
    'construction': 8, 'unclassified': 9,
    'np.nan': -1
}

base_dir = '../../../../data/pop_1pm_simulations/idf_1pm/'

# %%
# List all the files in the base_dir
files = os.listdir(base_dir)

for file in files:
    file_path = os.path.join(base_dir, file)
    base_name, ext = os.path.splitext(file)
    if base_name.startswith("idf_1pm_"):
        base_name = base_name.replace("idf_1pm_", "")
    var_name = base_name  # Start with the cleaned base name
    
    if file.endswith('.csv'):
        try:
            var_name = f"{var_name}_df"  
            globals()[var_name] = pd.read_csv(file_path, sep=";")
            print(f"Loaded CSV file: {file} into variable: {var_name}")
        except Exception as e:
            print(f"Error loading CSV file {file}: {e}")
            
    elif file.endswith('.gpkg'):
        try:
            var_name = f"{var_name}_gdf"  
            layers = fiona.listlayers(file_path)
            
            # Read each layer into a GeoDataFrame
            geodataframes = {layer: gpd.read_file(file_path, layer=layer, geometry = 'geometry', crs="EPSG:2154") for layer in layers}

            # Display the first few rows of each GeoDataFrame
            for layer, gdf in geodataframes.items():
                print(f"Layer: {layer}")
                gdf = gdf.to_crs(epsg=4326)
                
                globals()[var_name] = gdf
                print(f"Loaded GPKG file: {file} into variable: {var_name}")
        except Exception as e:
            print(f"Error loading CSV file {file}: {e}")
# Out:
# Loaded CSV file: idf_1pm_persons.csv into variable: persons_df
# Layer: idf_1pm_commutes
# Loaded GPKG file: idf_1pm_commutes.gpkg into variable: commutes_gdf
# Loaded CSV file: idf_1pm_households.csv into variable: households_df
# Loaded CSV file: idf_1pm_trips.csv into variable: trips_df
# Loaded CSV file: idf_1pm_activities.csv into variable: activities_df
# Loaded CSV file: idf_1pm_vehicle_types.csv into variable: vehicle_types_df
# Layer: idf_1pm_trips
# Loaded GPKG file: idf_1pm_trips.gpkg into variable: trips_gdf
# Layer: idf_1pm_activities
# Loaded GPKG file: idf_1pm_activities.gpkg into variable: activities_gdf
# Loaded CSV file: idf_1pm_vehicles.csv into variable: vehicles_df
# Layer: idf_1pm_homes
# Loaded GPKG file: idf_1pm_homes.gpkg into variable: homes_gdf

# %% [markdown]
# # Relevant dataframes are:
#
# activities_g
# commutes_g
# households_c
# trips_g
# vehicles_c

# %%
population_df = pd.read_csv("intermediate_results/population.csv")
transit_schedule_relations_df = pd.read_csv("intermediate_results/transit_schedule_relations.csv")
transit_schedule_stop_facilities_df = pd.read_csv("intermediate_results/transit_schedule_stop_facilities.csv")

# %%
# Sorting the DataFrame by the "id" column
sorted_population_df = population_df.sort_values(by="id")
sorted_persons_df = persons_df.sort_values(by="person_id")
merged_df = pd.merge(sorted_persons_df, sorted_population_df, left_on="person_id", right_on="id")
removed_some_columns = merged_df.copy()
removed_some_columns = removed_some_columns.drop(columns=['employed_y', 'hasPtSubscription', 'householdId', 'sex_y', 'htsPersonId', 'censusPersonId', 'hasLicense', 'id', 'age_y'])
updated_persons = removed_some_columns.copy()

# %%
updated_persons.head(20)
# Out:
#     person_id  household_id  age_x  employed_x   sex_x  \
# 0        1972          1084     23        True    male
# 1        1973          1084     23        True  female
# 2        2973          1590     39       False    male
# 3        5524          2921     32        True  female
# 4        5525          2921     31        True    male
# 5        7199          3784     71        True  female
# 6       14041          7514     67       False  female
# 7       14246          7606     31        True  female
# 8       16252          8634     44        True    male
# 9       16253          8634     74       False  female
# 10      17452          9241      2       False    male
# 11      17453          9241     37        True    male
# 12      17454          9241     36        True  female
# 13      17481          9255     33        True    male
# 14      17482          9255     32       False  female
# 15      17665          9353     45       False  female
# 16      18793          9930     74        True  female
# 17      22055         11736     84       False    male
# 18      22544         11989     31        True    male
# 19      26131         13828     30        True    male
#
#     socioprofessional_class  has_driving_license  has_pt_subscription  \
# 0                         4                 True                 True
# 1                         4                 True                 True
# 2                         6                 True                 True
# 3                         4                False                False
# 4                         5                False                False
# 5                         4                False                False
# 6                         7                 True                 True
# 7                         4                 True                 True
# 8                         3                 True                False
# 9                         7                 True                 True
# 10                        8                False                False
# 11                        3                False                False
# 12                        3                 True                 True
# 13                        4                 True                False
# 14                        5                False                 True
# 15                        8                False                 True
# 16                        5                False                False
# 17                        7                 True                False
# 18                        6                 True                False
# 19                        3                 True                 True
#
#     census_person_id  hts_id bikeAvailability carAvailability  \
# 0                749     982             none            none
# 1                750    1054             none            none
# 2               1143    5283             none            none
# 3               2058     442             some            none
# 4               2059    7081             some            none
# 5               2713    3604             none            none
# 6               5455     512             none            none
# 7               5533     840             none            none
# 8               6299    1206             none            some
# 9               6300    1297             none            some
# 10              6755    5814              all             all
# 11              6756    1174             some             all
# 12              6757   14917             some             all
# 13              6768    1276             some            none
# 14              6769    2379             none            none
# 15              6843    1807              all            none
# 16              7291    7333             none            none
# 17              8580    5246             none            none
# 18              8772    7210             none            none
# 19             10173     676             none            none
#
#     censusHouseholdId  householdIncome  htsHouseholdId  isPassenger  \
# 0                 410      1098.137370             463        False
# 1                 410      1098.137370             502        False
# 2                 615      3287.396810            2380        False
# 3                1106      2109.866062             177        False
# 4                1106      2109.866062            3077        False
# 5                1442      1556.330885            1667        False
# 6                2940      6192.562297             216        False
# 7                2975      1715.325021             380        False
# 8                3374      6272.979646             583        False
# 9                3374      6272.979646             636        False
# 10               3611      2322.615341            2583        False
# 11               3611      2322.615341             564        False
# 12               3611      2322.615341            6113        False
# 13               3618      2705.333535             624        False
# 14               3618      2705.333535            1194        False
# 15               3658      3756.122606             901        False
# 16               3886      2924.450221            3174        False
# 17               4597      1378.743358            2363        False
# 18               4701      1259.129638            3125        False
# 19               5418      3798.510215             293        False
#
#                                              vehicles
# 0   {"car":"1972:car","car_passenger":"1972:car_pa...
# 1   {"car":"1973:car","car_passenger":"1973:car_pa...
# 2   {"car":"2973:car","car_passenger":"2973:car_pa...
# 3   {"car":"5524:car","car_passenger":"5524:car_pa...
# 4   {"car":"5525:car","car_passenger":"5525:car_pa...
# 5   {"car":"7199:car","car_passenger":"7199:car_pa...
# 6   {"car":"14041:car","car_passenger":"14041:car_...
# 7   {"car":"14246:car","car_passenger":"14246:car_...
# 8   {"car":"16252:car","car_passenger":"16252:car_...
# 9   {"car":"16253:car","car_passenger":"16253:car_...
# 10  {"car":"17452:car","car_passenger":"17452:car_...
# 11  {"car":"17453:car","car_passenger":"17453:car_...
# 12  {"car":"17454:car","car_passenger":"17454:car_...
# 13  {"car":"17481:car","car_passenger":"17481:car_...
# 14  {"car":"17482:car","car_passenger":"17482:car_...
# 15  {"car":"17665:car","car_passenger":"17665:car_...
# 16  {"car":"18793:car","car_passenger":"18793:car_...
# 17  {"car":"22055:car","car_passenger":"22055:car_...
# 18  {"car":"22544:car","car_passenger":"22544:car_...
# 19  {"car":"26131:car","car_passenger":"26131:car_...

# %%
updated_persons['socioprofessional_class'].unique()
# Out:
# array([4, 6, 5, 7, 3, 8, 2, 1])

# %%
len(activities_gdf)
# Out:
# 50834

# %%
grouped  = activities_gdf.groupby('purpose')

# %%
for name, group in grouped:
    print(f"Group name: {name}")
    print(len(group))
# Out:
# Group name: education
# 3243
# Group name: home
# 28594
# Group name: leisure
# 4792
# Group name: other
# 4006
# Group name: shop
# 4433
# Group name: work
# 5766

# %%
activities_gdf.head()
# Out:
#    person_id  household_id  activity_index  preceding_trip_index  \
# 0       1972          1084               0                    -1
# 1       1972          1084               1                     0
# 2       1972          1084               2                     1
# 3       1973          1084               0                    -1
# 4       1973          1084               1                     0
#
#    following_trip_index  purpose  start_time  end_time  is_first  is_last  \
# 0                     0     home         NaN   67289.0      True    False
# 1                     1  leisure     69269.0   78089.0     False    False
# 2                    -1     home     79889.0       NaN     False     True
# 3                     0     home         NaN   33740.0      True    False
# 4                     1     work     35840.0   65240.0     False    False
#
#                    geometry
# 0  POINT (2.37653 48.86644)
# 1  POINT (2.32311 48.88089)
# 2  POINT (2.37653 48.86644)
# 3  POINT (2.37653 48.86644)
# 4  POINT (2.31411 48.87720)

# %%
len(activities_gdf[activities_gdf['purpose'] == 'home'])
# Out:
# 28594

# %%
activities_df.head()
# Out:
#    person_id  household_id  activity_index  preceding_trip_index  \
# 0       1972          1084               0                    -1
# 1       1972          1084               1                     0
# 2       1972          1084               2                     1
# 3       1973          1084               0                    -1
# 4       1973          1084               1                     0
#
#    following_trip_index  purpose  start_time  end_time  is_first  is_last
# 0                     0     home         NaN   67289.0      True    False
# 1                     1  leisure     69269.0   78089.0     False    False
# 2                    -1     home     79889.0       NaN     False     True
# 3                     0     home         NaN   33740.0      True    False
# 4                     1     work     35840.0   65240.0     False    False

# %%
homes_gdf.sort_values(by='household_id')
# Out:
#       household_id                  geometry
# 0             1084  POINT (2.37653 48.86644)
# 1             1590  POINT (2.37969 48.84590)
# 2             2921  POINT (2.32901 48.89036)
# 3             3784  POINT (2.36433 48.85736)
# 4             7514  POINT (2.31159 48.83649)
# ...            ...                       ...
# 5295       5479071  POINT (2.45167 48.98739)
# 5296       5479851  POINT (2.35626 49.07445)
# 5462       5479946  POINT (2.23220 48.95621)
# 5297       5481534  POINT (2.05988 49.04099)
# 5325       5482225  POINT (2.06198 49.03718)
#
# [5525 rows x 2 columns]

# %%
trips_gdf.head()
# Out:
#    person_id  trip_index  preceding_activity_index  following_activity_index  \
# 0       1972           0                         0                         1
# 1       1972           1                         1                         2
# 2       1973           0                         0                         1
# 3       1973           1                         1                         2
# 4       2973           0                         0                         1
#
#    departure_time  arrival_time preceding_purpose following_purpose  is_first  \
# 0         67289.0       69269.0              home           leisure      True
# 1         78089.0       79889.0           leisure              home     False
# 2         33740.0       35840.0              home              work      True
# 3         65240.0       67940.0              work              home     False
# 4         21976.0       24376.0              home              work      True
#
#    is_last                                         geometry
# 0    False  LINESTRING (2.37653 48.86644, 2.32311 48.88089)
# 1     True  LINESTRING (2.32311 48.88089, 2.37653 48.86644)
# 2    False  LINESTRING (2.37653 48.86644, 2.31411 48.87720)
# 3     True  LINESTRING (2.31411 48.87720, 2.37653 48.86644)
# 4    False  LINESTRING (2.37969 48.84590, 2.54708 49.00713)

# %%
len(trips_gdf)
# Out:
# 38293

# %%
transit_schedule_relations_df.head()
# Out:
#                  fromStop                  toStop  transferTime
# 0  IDFM:35594.link:260959  IDFM:35593.link:260960          60.0
# 1  IDFM:24454.link:143141  IDFM:24452.link:322682         300.0
# 2  IDFM:24454.link:143141  IDFM:25273.link:378656         333.0
# 3  IDFM:24454.link:143141   IDFM:35823.link:52729         253.0
# 4  IDFM:24454.link:143141  IDFM:24455.link:322683         262.0

# %%
transit_schedule_stop_facilities_df
# Out:
#                                               id linkRefId              x  \
# 0                         IDFM:10001.link:347106    347106  640646.000048
# 1                         IDFM:10002.link:347105    347105  640643.000048
# 2                         IDFM:10003.link:485992    485992  627418.000058
# 3                         IDFM:10003.link:485993    485993  627418.000058
# 4                         IDFM:10004.link:485995    485995  627406.000058
# ...                                          ...       ...            ...
# 42611  IDFM:monomodalStopPlace:58879.link:287964    287964  669441.500024
# 42612  IDFM:monomodalStopPlace:58937.link:557193    557193  669182.653025
# 42613  IDFM:monomodalStopPlace:58937.link:704712    704712  669182.653025
# 42614  IDFM:monomodalStopPlace:59206.link:398937    398937  648412.609741
# 42615  IDFM:monomodalStopPlace:59206.link:534367    534367  648412.609741
#
#                   y                name  stopAreaId  isBlocking
# 0      6.880849e+06    Les Châtaigniers  IDFM:66540       False
# 1      6.880827e+06    Les Châtaigniers  IDFM:66540       False
# 2      6.856641e+06  Erich Von Stroheim  IDFM:63975       False
# 3      6.856641e+06  Erich Von Stroheim  IDFM:63975       False
# 4      6.856090e+06          Fritz Lang  IDFM:63913       False
# ...             ...                 ...         ...         ...
# 42611  6.863869e+06   Chelles - Gournay  IDFM:68407       False
# 42612  6.860398e+06      Noisy - Champs  IDFM:73163       False
# 42613  6.860398e+06      Noisy - Champs  IDFM:73163       False
# 42614  6.853698e+06              Sceaux  IDFM:74265       False
# 42615  6.853698e+06              Sceaux  IDFM:74265       False
#
# [42616 rows x 7 columns]
